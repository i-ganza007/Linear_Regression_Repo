# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pandas as pd

# %%
data = pd.read_csv('canada_per_capita_income.csv')
print(data.head())
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
model = sk.linear_model.LinearRegression()
x_train = data['year'].head(50).values.reshape(-1,1)
y_train = data['per capita income (US$)'].head(50).values
#print(x_train,y_train)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_train)
# Equation is Y = 828.46507522(X) -1632210.7578554575 
print(model.coef_)
print(model.intercept_)
# Out:
# [828.46507522]
# -1632210.7578554575

# %%
plt.scatter(x_train,y_train,marker='+',color='green')
plt.plot(x_train,y_pred)
plt.ylabel('Per Capita Income (US$)')
plt.xlabel('Year')
plt.show()
